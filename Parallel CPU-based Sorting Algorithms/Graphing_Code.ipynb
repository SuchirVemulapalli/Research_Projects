# %%
#array of fixed size 20000
import matplotlib.pyplot as plt
threads = [1,2,4,8]
timeParallelMergeSortJava = [4271700,2684100,2913300,1044500]
#timeParallelMergeSortPython = [17,50,73,89]
timeParallelQuickSortJava = [1708100,932200,553200,480400]
#timeParallelQuickSortPython = [32,70,47,49]
#timeParallelBitonicSortJava = [30917209498,16173054081,8307189388,4631250452]
#timeParallelBrickSortPython = [17,50,73,89]
#timeParallelBrickSortJava = [1213519501,2089719608,3122871165,3320862469]
#timeParallelBitonicSortPython = [31856,14636,10198,5852]
plt.plot(threads, timeParallelMergeSortJava, marker = 'o', linestyle = '-', label = 'Parallel Merge Sort')
#plt.plot(threads, timeParallelMergeSortPython, marker = 'o', linestyle = '-', label = 'parallel merge sort python')
plt.plot(threads, timeParallelQuickSortJava, marker = 'o', linestyle = '-', label = 'Parallel Quick Sort')
#plt.plot(threads, timeParallelQuickSortPython, marker = 'o', linestyle = '-', label = 'parallel quick sort python')
#plt.plot(threads, timeParallelBrickSortJava, marker = 'o', linestyle = '-', label = 'parallel brick sort java')
#plt.plot(threads, timeParallelBrickSortPython, marker = 'o', linestyle = '-', label = 'parallel brick sort python')
#plt.plot(threads, timeParallelBitonicSortJava, marker = 'o', linestyle = '-', label = 'parallel bitonic sort java')
#plt.plot(threads, timeParallelBitonicSortPython, marker = 'o', linestyle = '-', label = 'parallel bitonic sort python')
plt.legend()
plt.title("Quick and Merge Sort vs # of threads")
plt.xlabel("# of threads")
plt.ylabel("seconds (ns)")
plt.show()

# %%
# fixed # of the threads = 8
import matplotlib.pyplot as plt
inputSize = [10,100,1000,10000,100000]
timeParallelMergeSortJava = [24700,41100,101000,554600,5570900]
#timeParallelMergeSortPython = [17,50,73,89]
timeParallelQuickSortJava = [25000,33400,67000,266300,2164200]
#timeParallelQuickSortPython = [32,70,47,49]
#timeParallelBitonicSortJava = [2486200,13796667,16500743,1161760373,70026638858]
#timeParallelBrickSortPython = [17,50,73,89]
#timeParallelBrickSortJava = [4525198,4527014,24115187,1135638807,77398872614]
#timeParallelBitonicSortPython = [32,70,47,49]
plt.loglog(inputSize, timeParallelMergeSortJava, marker = 'o', linestyle = '-', label = 'Parallel Merge Sort ')
#plt.plot(cores, timeParallelMergeSortPython, marker = 'o', linestyle = '-', label = 'parallel merge sort python')
plt.loglog(inputSize, timeParallelQuickSortJava, marker = 'o', linestyle = '-', label = 'Parallel Quick Sort ')
#plt.plot(cores, timeParallelQuickSortPython, marker = 'o', linestyle = '-', label = 'parallel quick sort python')
#plt.plot(inputSize, timeParallelBrickSortJava, marker = 'o', linestyle = '-', label = 'parallel brick sort ')
#plt.plot(cores, timeParallelBrickSortPython, marker = 'o', linestyle = '-', label = 'parallel brick sort python')
#plt.plot(inputSize, timeParallelBitonicSortJava, marker = 'o', linestyle = '-', label = 'parallel bitonic sort')
#plt.plot(cores, timeParallelBitonicSortPython, marker = 'o', linestyle = '-', label = 'parallel bitonic sort python')
plt.legend()
plt.title("Quick and Merge Sort vs array input")
plt.xlabel("Array input size")
plt.ylabel("seconds (ns)")
plt.show()

# %%
# fixed # of the threads = 8
import matplotlib.pyplot as plt
inputSize = [1,2,4,8]
#timeParallelMergeSortJava = [41100,24700,101000,554600,5570900]
#timeParallelMergeSortPython = [17,50,73,89]
#timeParallelQuickSortJava = [25000,33400,67000,266300,2164200]
#timeParallelQuickSortPython = [32,70,47,49]
timeParallelBitonicSortJava = [30917209498,16173054081,8307189388,4631250452]
#timeParallelBrickSortPython = [17,50,73,89]
timeParallelBrickSortJava = [1213519501,2089719608,3122871165,3320862469]#timeParallelBitonicSortPython = [32,70,47,49]
#plt.plot(inputSize, timeParallelMergeSortJava, marker = 'o', linestyle = '-', label = 'parallel merge sort ')
#plt.plot(cores, timeParallelMergeSortPython, marker = 'o', linestyle = '-', label = 'parallel merge sort python')
#plt.plot(inputSize, timeParallelQuickSortJava, marker = 'o', linestyle = '-', label = 'parallel quick sort ')
#plt.plot(cores, timeParallelQuickSortPython, marker = 'o', linestyle = '-', label = 'parallel quick sort python')
plt.plot(inputSize, timeParallelBrickSortJava, marker = 'o', linestyle = '-', label = 'Parallel Brick Sort ')
#plt.plot(cores, timeParallelBrickSortPython, marker = 'o', linestyle = '-', label = 'parallel brick sort python')
plt.plot(inputSize, timeParallelBitonicSortJava, marker = 'o', linestyle = '-', label = 'Parallel Bitonic Sort')
#plt.plot(cores, timeParallelBitonicSortPython, marker = 'o', linestyle = '-', label = 'parallel bitonic sort python')
plt.legend()
plt.title("Bitonic and Brick Sort vs # of threads")
plt.xlabel("# of threads")
plt.ylabel("seconds (ns)")
plt.show()

# %%
# fixed # of the threads = 8
import matplotlib.pyplot as plt
inputSize = [10,100,1000,10000,100000]
#timeParallelMergeSortJava = [41100,24700,101000,554600,5570900]
#timeParallelMergeSortPython = [17,50,73,89]
#timeParallelQuickSortJava = [25000,33400,67000,266300,2164200]
#timeParallelQuickSortPython = [32,70,47,49]
timeParallelBitonicSortJava = [2486200,13796667,16500743,1161760373,70026638858]
#timeParallelBrickSortPython = [17,50,73,89]
timeParallelBrickSortJava = [4525198,4527014,24115187,1135638807,77398872614]
#timeParallelBitonicSortPython = [32,70,47,49]
#plt.plot(inputSize, timeParallelMergeSortJava, marker = 'o', linestyle = '-', label = 'parallel merge sort ')
#plt.plot(cores, timeParallelMergeSortPython, marker = 'o', linestyle = '-', label = 'parallel merge sort python')
#plt.plot(inputSize, timeParallelQuickSortJava, marker = 'o', linestyle = '-', label = 'parallel quick sort ')
#plt.plot(cores, timeParallelQuickSortPython, marker = 'o', linestyle = '-', label = 'parallel quick sort python')
plt.loglog(inputSize, timeParallelBrickSortJava, marker = 'o', linestyle = '-', label = 'Parallel Brick Sort ')
#plt.plot(cores, timeParallelBrickSortPython, marker = 'o', linestyle = '-', label = 'parallel brick sort python')
plt.loglog(inputSize, timeParallelBitonicSortJava, marker = 'o', linestyle = '-', label = 'Parallel Bitonic Sort')
#plt.plot(cores, timeParallelBitonicSortPython, marker = 'o', linestyle = '-', label = 'parallel bitonic sort python')
plt.legend()
plt.title("Bitonic and Brick Sort vs array input")
plt.xlabel("Array input size")
plt.ylabel("seconds (ns)")
plt.show()

# %%
# fixed # of the threads = 8
import matplotlib.pyplot as plt
inputSize = [10,100,1000,10000,100000]
timeSequentialMergeSortJava = [26200, 219300, 2263100, 9624200, 79966000]
timeParallelMergeSortJava = [24700,41100,101000,554600,5570900]
#timeParallelQuickSortJava = [25000,33400,67000,266300,2164200]
#timeParallelQuickSortPython = [32,70,47,49]
#timeParallelBitonicSortJava = [2486200,13796667,16500743,1161760373,70026638858]
#timeParallelBrickSortPython = [17,50,73,89]
#timeParallelBrickSortJava = [4525198,4527014,24115187,1135638807,77398872614]
#timeParallelBitonicSortPython = [32,70,47,49]
plt.loglog(inputSize, timeSequentialMergeSortJava, marker = 'o', linestyle = '-', label = 'Sequential Merge Sort')
plt.loglog(inputSize, timeParallelMergeSortJava, marker = 'o', linestyle = '-', label = 'Parallel Merge Sort')
#plt.plot(inputSize, timeParallelQuickSortJava, marker = 'o', linestyle = '-', label = 'parallel quick sort ')
#plt.plot(cores, timeParallelQuickSortPython, marker = 'o', linestyle = '-', label = 'parallel quick sort python')
#plt.loglog(inputSize, timeParallelBrickSortJava, marker = 'o', linestyle = '-', label = 'Parallel Brick Sort ')
#plt.plot(cores, timeParallelBrickSortPython, marker = 'o', linestyle = '-', label = 'parallel brick sort python')
#plt.loglog(inputSize, timeParallelBitonicSortJava, marker = 'o', linestyle = '-', label = 'Parallel Bitonic Sort')
#plt.plot(cores, timeParallelBitonicSortPython, marker = 'o', linestyle = '-', label = 'parallel bitonic sort python')
plt.legend()
plt.title("Sequential & Parallel Merge Sort vs array input")
plt.xlabel("Array input size")
plt.ylabel("seconds (ns)")
plt.show()

# %%
# fixed # of the threads = 8
import matplotlib.pyplot as plt
inputSize = [10,100,1000,10000,100000]
timeParallelMergeSortJava = [25000,33400,67000,266300,2164200]
#timeParallelMergeSortPython = [17,50,73,89]
timeSequentialQuickSortJava = [25000, 180900, 1674500, 7082000, 38946000]
#timeParallelQuickSortPython = [32,70,47,49]
#timeParallelBitonicSortJava = [2486200,13796667,16500743,1161760373,70026638858]
#timeParallelBrickSortPython = [17,50,73,89]
#timeParallelBrickSortJava = [4525198,4527014,24115187,1135638807,77398872614]
#timeParallelBitonicSortPython = [32,70,47,49]
#plt.plot(inputSize, timeParallelMergeSortJava, marker = 'o', linestyle = '-', label = 'parallel merge sort ')
#plt.plot(cores, timeParallelMergeSortPython, marker = 'o', linestyle = '-', label = 'parallel merge sort python')
plt.loglog(inputSize, timeSequentialQuickSortJava, marker = 'o', linestyle = '-', label = 'Sequential Quick Sort')
plt.loglog(inputSize, timeParallelQuickSortJava, marker = 'o', linestyle = '-', label = 'Parallel Quick Sort')
#plt.loglog(inputSize, timeParallelBrickSortJava, marker = 'o', linestyle = '-', label = 'Parallel Brick Sort ')
#plt.plot(cores, timeParallelBrickSortPython, marker = 'o', linestyle = '-', label = 'parallel brick sort python')
#plt.loglog(inputSize, timeParallelBitonicSortJava, marker = 'o', linestyle = '-', label = 'Parallel Bitonic Sort')
#plt.plot(cores, timeParallelBitonicSortPython, marker = 'o', linestyle = '-', label = 'parallel bitonic sort python')
plt.legend()
plt.title("Sequential & Parallel Quick Sort vs array input")
plt.xlabel("Array input size")
plt.ylabel("seconds (ns)")
plt.show()

# %%
# fixed # of the threads = 8
import matplotlib.pyplot as plt
inputSize = [10,100,1000,10000,100000]
#timeParallelMergeSortJava = [41100,24700,101000,554600,5570900]
#timeParallelMergeSortPython = [17,50,73,89]
#timeParallelQuickSortJava = [25000,33400,67000,266300,2164200]
#timeParallelQuickSortPython = [32,70,47,49]
#timeParallelBitonicSortJava = [2486200,13796667,16500743,1161760373,70026638858]
timeParallelBrickSortJava = [2486200,13796667,16500743,1161760373,70026638858]
timeSequentialBrickSortJava = [12100, 442800, 12364600, 176700600, 14226981600]
#timeParallelBitonicSortPython = [32,70,47,49]
#plt.plot(inputSize, timeParallelMergeSortJava, marker = 'o', linestyle = '-', label = 'parallel merge sort ')
#plt.plot(cores, timeParallelMergeSortPython, marker = 'o', linestyle = '-', label = 'parallel merge sort python')
#plt.plot(inputSize, timeParallelQuickSortJava, marker = 'o', linestyle = '-', label = 'parallel quick sort ')
#plt.plot(cores, timeParallelQuickSortPython, marker = 'o', linestyle = '-', label = 'parallel quick sort python')
plt.loglog(inputSize, timeSequentialBrickSortJava, marker = 'o', linestyle = '-', label = 'Sequential Brick Sort ')
plt.plot(inputSize, timeParallelBrickSortJava, marker = 'o', linestyle = '-', label = 'Parallel Brick Sort')
#plt.loglog(inputSize, timeParallelBitonicSortJava, marker = 'o', linestyle = '-', label = 'Parallel Bitonic Sort')
#plt.plot(cores, timeParallelBitonicSortPython, marker = 'o', linestyle = '-', label = 'parallel bitonic sort python')
plt.legend()
plt.title("Sequential & Parallel Brick Sort vs array input")
plt.xlabel("Array input size")
plt.ylabel("seconds (ns)")
plt.show()

# %%
# fixed # of the threads = 8
import matplotlib.pyplot as plt
inputSize = [10,100,1000,10000,100000]
#timeParallelMergeSortJava = [41100,24700,101000,554600,5570900]
#timeParallelMergeSortPython = [17,50,73,89]
#timeParallelQuickSortJava = [25000,33400,67000,266300,2164200]
#timeParallelQuickSortPython = [32,70,47,49]
timeSequentialBitonicSortJava = [46400, 426300, 2705400, 25230100, 131940000]
#timeParallelBrickSortPython = [17,50,73,89]
#timeParallelBrickSortJava = [4525198,4527014,24115187,1135638807,77398872614]
timeParallelBitonicSortJava = [2486200,13796667,16500743,1161760373,70026638858]
#plt.plot(inputSize, timeParallelMergeSortJava, marker = 'o', linestyle = '-', label = 'parallel merge sort ')
#plt.plot(cores, timeParallelMergeSortPython, marker = 'o', linestyle = '-', label = 'parallel merge sort python')
#plt.plot(inputSize, timeParallelQuickSortJava, marker = 'o', linestyle = '-', label = 'parallel quick sort ')
#plt.plot(cores, timeParallelQuickSortPython, marker = 'o', linestyle = '-', label = 'parallel quick sort python')
#plt.loglog(inputSize, timeParallelBrickSortJava, marker = 'o', linestyle = '-', label = 'Parallel Brick Sort ')
#plt.plot(cores, timeParallelBrickSortPython, marker = 'o', linestyle = '-', label = 'parallel brick sort python')
plt.loglog(inputSize, timeSequentialBitonicSortJava, marker = 'o', linestyle = '-', label = 'Sequential Bitonic Sort')
plt.plot(inputSize, timeParallelBitonicSortJava, marker = 'o', linestyle = '-', label = 'Parallel Bitonic Sort')
plt.legend()
plt.title("Sequential & Parallel Bitonic Sort vs array input")
plt.xlabel("Array input size")
plt.ylabel("seconds (ns)")
plt.show()
